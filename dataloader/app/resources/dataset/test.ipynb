# %%
import json
f = "release_evidences.json"
with open(f) as f:
    evidences = json.load(f)

# %%
# for every evidence print name and question_en and ---
for k, v in evidences.items():
    print(k, v['name'], "\n", v['question_en'])
    print('---')
# Out:
# fievre fievre
#  Do you have a fever (either felt or measured with a thermometer)?
# ---
# douleurxx_endroitducorps douleurxx_endroitducorps
#  Do you feel pain somewhere?
# ---
# douleurxx douleurxx
#  Do you have pain somewhere, related to your reason for consulting?
# ---
# douleurxx_irrad douleurxx_irrad
#  Does the pain radiate to another location?
# ---
# douleurxx_carac douleurxx_carac
#  Characterize your pain:
# ---
# douleurxx_soudain douleurxx_soudain
#  How fast did the pain appear?
# ---
# douleurxx_intens douleurxx_intens
#  How intense is the pain?
# ---
# douleurxx_precis douleurxx_precis
#  How precisely is the pain located?
# ---
# pdc pdc
#  Did you lose consciousness?
# ---
# lesions_peau_endroitducorps lesions_peau_endroitducorps
#  Where is the affected region located?
# ---
# lesions_peau lesions_peau
#  Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
# ---
# ...
